# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import os
import pickle

# %%
# 티커명을 저장한 파일 로드
tickers_file = 'tickers.csv'

# 이전에 저장된 티커명을 로드
if os.path.exists(tickers_file):
    df = pd.read_csv(tickers_file)
    tickers = df["Tickers"].tolist()
    tickers = [str(x) for x in tickers]
    tickers.sort()

# %%
# 재무 정보를 저장할 최종 csv 파일
financial_results = 'financial_results.csv'

# 이전에 저장된 파일을 로드(이미 저장된 경우)
if os.path.exists(financial_results):
    # CSV 파일에서 데이터 읽기
    results_df = pd.read_csv(financial_results, index_col=0)
else:
    results_df = pd.DataFrame(columns=['Index', 'Market Cap', 'Income', 'Sales', 'Book/sh', 'Cash/sh', 'Dividend Est.', 'Dividend TTM', 'Dividend Ex-Date', 'Employees', 'Option/Short', 'Sales Surprise', 'SMA20', 'P/E', 'Forward P/E', 'PEG', 'P/S', 'P/B', 'P/C', 'P/FCF', 'Quick Ratio', 'Current Ratio', 'Debt/Eq', 'LT Debt/Eq', 'EPS Surprise', 'SMA50', 'EPS (ttm)', 'EPS next Y', 'EPS next Q', 'EPS this Y', 'EPS next Y', 'EPS next 5Y', 'EPS past 5Y', 'Sales past 5Y', 'EPS Y/Y TTM', 'Sales Y/Y TTM', 'EPS Q/Q', 'Sales Q/Q', 'SMA200', 'Insider Own', 'Insider Trans', 'Inst Own', 'Inst Trans', 'ROA', 'ROE', 'ROI', 'Gross Margin', 'Oper. Margin', 'Profit Margin', 'Payout', 'Earnings', 'Trades', 'Shs Outstand', 'Shs Float', 'Short Float', 'Short Ratio', 'Short Interest', '52W Range', '52W High', '52W Low', 'RSI (14)', 'Recom', 'Rel Volume', 'Avg Volume', 'Volume', 'Perf Week', 'Perf Month', 'Perf Quarter', 'Perf Half Y', 'Perf Year', 'Perf YTD', 'Beta', 'ATR (14)', 'Volatility', 'Target Price', 'Prev Close', 'Price', 'Change']) # 만약 파일이 없다면 빈 데이터프레임 생성

start_ticker = tickers[len(results_df)] # 저장한 지점 다음의 티커
start_ticker_index = len(results_df)

# %%
results_df
# Out:
#                     Index Market Cap    Income    Sales Book/sh Cash/sh  \
# A                 S&P 500     37.42B     1.41B    6.50B   20.53    6.19
# AA                      -     10.65B  -292.00M   10.91B   20.32    5.27
# AACG                    -     32.60M    -5.67M   34.79M    0.30    0.18
# AACT                    -    681.25M    26.89M    0.00M    8.36    0.02
# AADI                    -     53.48M   -61.69M   25.07M    2.80    2.54
# AAL                     -      9.37B   275.00M   53.61B   -7.39   14.04
# AAM                     -    529.16M         -        -    7.75    0.01
# AAM-U                   -          -         -        -       -       -
# AAME                    -     34.68M    -7.31M  185.93M    5.18       -
# AAOI                  RUT      1.27B   -80.90M  209.55M    4.73    0.92
# AAON                    -     10.82B   190.92M    1.21B    9.81    0.08
# AAP                     -      2.46B     1.24M   11.27B   43.68    8.03
# ...

# %%
for ticker in tickers[start_ticker_index:]:
    print(f"현재 탐색 티커 : {ticker}")
    url = f'https://finviz.com/quote.ashx?t={ticker}&p=d'
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36',
        'Referer': 'https://example.com',
        'Accept-Language': 'ko-KR,ko;q=0.9',
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8',
        'Connection': 'keep-alive'
    }
    
    res = requests.get(url, headers=headers)
    while res.status_code == 429:
        print("너무 많은 요청.. 재시도")
        time.sleep(random.uniform(3,5))
        res = requests.get(url, headers=headers)
        
    soup = BeautifulSoup(res.text, "html.parser")

    # 테이블 찾기
    table = soup.find("table",{"class" : "snapshot-table2"})
    
    # 테이블의 모든 행 찾기
    rows = table.find_all("tr")
    
    # 데이터 저장
    table_data = []
    
    for row in rows:
        cells = row.find_all("td")
        row_data = [cell.get_text(strip=True) for cell in cells]
        table_data.append(row_data)
    
    
    # 데이터프레임으로 변환
    df = pd.DataFrame(table_data)
    df = df.reset_index(drop=True)

    index_list = []
    value_list = []
    for i in range(0,12,2):
        value_list.extend(df[i+1].tolist())
    results_df.loc[ticker] = value_list
    results_df.to_csv('financial_results.csv',index=True)
# Out:
# 현재 탐색 티커 : ACI
# 현재 탐색 티커 : ACIC
# 현재 탐색 티커 : ACIU
# 현재 탐색 티커 : ACIW
# 현재 탐색 티커 : ACLS
# 현재 탐색 티커 : ACLX
# 현재 탐색 티커 : ACM
# 현재 탐색 티커 : ACMR
# 현재 탐색 티커 : ACN
# 현재 탐색 티커 : ACNB
# 현재 탐색 티커 : ACNT
# 현재 탐색 티커 : ACOG
# 현재 탐색 티커 : ACON
# 현재 탐색 티커 : ACR
# 현재 탐색 티커 : ACRE
# 현재 탐색 티커 : ACRS
# 현재 탐색 티커 : ACRV
# 현재 탐색 티커 : ACT
# 현재 탐색 티커 : ACTG
# 현재 탐색 티커 : ACTU
# 현재 탐색 티커 : ACU
# 현재 탐색 티커 : ACVA
# 현재 탐색 티커 : ACXP
# 현재 탐색 티커 : ADAG
# 현재 탐색 티커 : ADAP
# 현재 탐색 티커 : ADBE
# 현재 탐색 티커 : ADC
# 현재 탐색 티커 : ADCT
# 현재 탐색 티커 : ADD
# 현재 탐색 티커 : ADEA
# 현재 탐색 티커 : ADGM
# 현재 탐색 티커 : ADI
# 현재 탐색 티커 : ADIL
# 현재 탐색 티커 : ADM
# 현재 탐색 티커 : ADMA
# 현재 탐색 티커 : ADN
# 현재 탐색 티커 : ADNT
# 현재 탐색 티커 : ADP
# 현재 탐색 티커 : ADPT
# 현재 탐색 티커 : ADSE
# 현재 탐색 티커 : ADSK
# 현재 탐색 티커 : ADT
# 현재 탐색 티커 : ADTN
# 현재 탐색 티커 : ADTX
# 현재 탐색 티커 : ADUR
# 현재 탐색 티커 : ADUS
# 현재 탐색 티커 : ADV
# 현재 탐색 티커 : ADVM
# 현재 탐색 티커 : ADXN
# 현재 탐색 티커 : AE
# 현재 탐색 티커 : AEAE
# 현재 탐색 티커 : AEE
# 현재 탐색 티커 : AEG
# 현재 탐색 티커 : AEHL
# 현재 탐색 티커 : AEHR
# 현재 탐색 티커 : AEI
# ...

# %%
results_df
# Out:
#                     Index Market Cap    Income    Sales Book/sh Cash/sh  \
# A                 S&P 500     37.42B     1.41B    6.50B   20.53    6.19
# AA                      -     10.65B  -292.00M   10.91B   20.32    5.27
# AACG                    -     32.60M    -5.67M   34.79M    0.30    0.18
# AACT                    -    681.25M    26.89M    0.00M    8.36    0.02
# AADI                    -     53.48M   -61.69M   25.07M    2.80    2.54
# AAL                     -      9.37B   275.00M   53.61B   -7.39   14.04
# AAM                     -    529.16M         -        -    7.75    0.01
# AAM-U                   -          -         -        -       -       -
# AAME                    -     34.68M    -7.31M  185.93M    5.18       -
# AAOI                  RUT      1.27B   -80.90M  209.55M    4.73    0.92
# AAON                    -     10.82B   190.92M    1.21B    9.81    0.08
# AAP                     -      2.46B     1.24M   11.27B   43.68    8.03
# ...

# %%
index = ['Index', 'Market Cap', 'Income', 'Sales', 'Book/sh', 'Cash/sh', 'Dividend Est.', 'Dividend TTM', 'Dividend Ex-Date', 'Employees', 'Option/Short', 'Sales Surprise', 'SMA20', 'P/E', 'Forward P/E', 'PEG', 'P/S', 'P/B', 'P/C', 'P/FCF', 'Quick Ratio', 'Current Ratio', 'Debt/Eq', 'LT Debt/Eq', 'EPS Surprise', 'SMA50', 'EPS (ttm)', 'EPS next Y', 'EPS next Q', 'EPS this Y', 'EPS next Y', 'EPS next 5Y', 'EPS past 5Y', 'Sales past 5Y', 'EPS Y/Y TTM', 'Sales Y/Y TTM', 'EPS Q/Q', 'Sales Q/Q', 'SMA200', 'Insider Own', 'Insider Trans', 'Inst Own', 'Inst Trans', 'ROA', 'ROE', 'ROI', 'Gross Margin', 'Oper. Margin', 'Profit Margin', 'Payout', 'Earnings', 'Trades', 'Shs Outstand', 'Shs Float', 'Short Float', 'Short Ratio', 'Short Interest', '52W Range', '52W High', '52W Low', 'RSI (14)', 'Recom', 'Rel Volume', 'Avg Volume', 'Volume', 'Perf Week', 'Perf Month', 'Perf Quarter', 'Perf Half Y', 'Perf Year', 'Perf YTD', 'Beta', 'ATR (14)', 'Volatility', 'Target Price', 'Prev Close', 'Price', 'Change']

len(index)
# Out:
# 78

# %%
print(value_list)
print(len(value_list))
# Out:
# ['-', '53.48M', '-61.69M', '25.07M', '2.80', '2.54', '-', '-', '-', '89', 'Yes / Yes', '9.36%', '5.74%', '-', '-', '-', '2.13', '0.78', '0.85', '-', '4.54', '4.89', '0.01', '0.01', '-0.55%', '9.49%', '-2.29', '-1.01', '-0.31', '18.75%', '48.93%', '-', '11.87%', '225.26%', '3.12%', '7.80%', '23.31%', '21.03%', '17.86%', '27.20%', '-2.47%', '53.20%', '18.93%', '-54.75%', '-65.95%', '-88.77%', '87.39%', '-253.63%', '-246.06%', '-', 'Nov 06 BMO', '', '24.55M', '17.94M', '1.57%', '1.23', '0.28M', '1.21 - 5.70', '-61.93%', '79.34%', '63.65', '3.00', '0.35', '228.10K', '79,738', '3.33%', '1.40%', '47.62%', '13.32%', '-54.51%', '7.43%', '0.70', '0.11', '7.27% 5.01%', '1.88', '2.17', '2.17', '0.00%']
# 78

# %%
print(value_list)
print(len(value_list))
# Out:
# ['-', '53.48M', '-61.69M', '25.07M', '2.80', '2.54', '-', '-', '-', '89', 'Yes / Yes', '9.36%', '5.74%', '-', '-', '-', '2.13', '0.78', '0.85', '-', '4.54', '4.89', '0.01', '0.01', '-0.55%', '9.49%', '-2.29', '-1.01', '-0.31', '18.75%', '48.93%', '-', '11.87%', '225.26%', '3.12%', '7.80%', '23.31%', '21.03%', '17.86%', '27.20%', '-2.47%', '53.20%', '18.93%', '-54.75%', '-65.95%', '-88.77%', '87.39%', '-253.63%', '-246.06%', '-', 'Nov 06 BMO', '', '24.55M', '17.94M', '1.57%', '1.23', '0.28M', '1.21 - 5.70', '-61.93%', '79.34%', '63.65', '3.00', '0.35', '228.10K', '79,738', '3.33%', '1.40%', '47.62%', '13.32%', '-54.51%', '7.43%', '0.70', '0.11', '7.27% 5.01%', '1.88', '2.17', '2.17', '0.00%']
# 78
